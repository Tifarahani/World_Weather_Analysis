# %%
from config import weather_api_key, g_key
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from citipy import citipy
import requests
from datetime import datetime
import time
from scipy.stats import linregress
import gmaps

# %%
lats = np.random.uniform(-90, 90, size=2000)
lngs = np.random.uniform(-180, 180, size=2000)

coordinates = zip(lats, lngs)
cities = []


for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    if city not in cities:
        cities.append(city)

# %%
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID="

city_data = []

print("Beginning Data Retrieval     ")
print("-----------------------------")

record_count = 1
set_count = 1

for i, city in enumerate(cities):
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        
    
    city_url = url + weather_api_key + "&q=" + city.replace(" ", "+")
    
    try:
        city_weather = requests.get(city_url).json()
        
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_description = city_weather["weather"][0]["description"]
        city_country = city_weather["sys"]["country"]
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime("%Y-%m-%d %H:%M:%S")

        
        city_data.append({
                          "City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_description,
                          "Country": city_country,
                          "Date": city_date
                        })
        
    except KeyError:
        print("City not found. Skipping...")
        continue
        
    print(f"Processing record count {record_count} of set {set_count} | {city}")
    record_count += 1
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing record count 1 of set 1 | hermanus
# Processing record count 2 of set 1 | bluff
# Processing record count 3 of set 1 | puerto ayora
# Processing record count 4 of set 1 | sao miguel do araguaia
# Processing record count 5 of set 1 | dajal
# Processing record count 6 of set 1 | shingu
# Processing record count 7 of set 1 | soto
# Processing record count 8 of set 1 | kaitangata
# Processing record count 9 of set 1 | ushuaia
# Processing record count 10 of set 1 | jamestown
# Processing record count 11 of set 1 | talnakh
# Processing record count 12 of set 1 | ponta do sol
# Processing record count 13 of set 1 | los llanos de aridane
# Processing record count 14 of set 1 | barabai
# Processing record count 15 of set 1 | rikitea
# Processing record count 16 of set 1 | busselton
# Processing record count 17 of set 1 | thai binh
# Processing record count 18 of set 1 | mayo
# Processing record count 19 of set 1 | saskylakh
# Processing record count 20 of set 1 | mar del plata
# Processing record count 21 of set 1 | lagoa
# Processing record count 22 of set 1 | griffith
# Processing record count 23 of set 1 | kapaa
# Processing record count 24 of set 1 | butaritari
# Processing record count 25 of set 1 | saint-philippe
# Processing record count 26 of set 1 | pisco
# Processing record count 27 of set 1 | barrow
# City not found. Skipping...
# Processing record count 28 of set 1 | diffa
# City not found. Skipping...
# Processing record count 29 of set 1 | albany
# Processing record count 30 of set 1 | cherskiy
# Processing record count 31 of set 1 | fairbanks
# Processing record count 32 of set 1 | whitehorse
# Processing record count 33 of set 1 | seka
# Processing record count 34 of set 1 | galle
# City not found. Skipping...
# Processing record count 35 of set 1 | castro
# Processing record count 36 of set 1 | karratha
# Processing record count 37 of set 1 | bredasdorp
# Processing record count 38 of set 1 | srednekolymsk
# Processing record count 39 of set 1 | auki
# Processing record count 40 of set 1 | bronnoysund
# Processing record count 41 of set 1 | hithadhoo
# Processing record count 42 of set 1 | cayenne
# City not found. Skipping...
# Processing record count 43 of set 1 | colares
# Processing record count 44 of set 1 | salinas
# Processing record count 45 of set 1 | nikolskoye
# Processing record count 46 of set 1 | ilava
# Processing record count 1 of set 2 | hobart
# Processing record count 2 of set 2 | cunduacan
# Processing record count 3 of set 2 | thompson
# Processing record count 4 of set 2 | esperance
# Processing record count 5 of set 2 | warwick
# Processing record count 6 of set 2 | vlore
# Processing record count 7 of set 2 | santo antonio do leverger
# City not found. Skipping...
# City not found. Skipping...
# Processing record count 8 of set 2 | port macquarie
# Processing record count 9 of set 2 | guerrero negro
# Processing record count 10 of set 2 | hasaki
# Processing record count 11 of set 2 | ribeira brava
# Processing record count 12 of set 2 | port alfred
# Processing record count 13 of set 2 | cabo san lucas
# Processing record count 14 of set 2 | mitsamiouli
# Processing record count 15 of set 2 | ngama
# Processing record count 16 of set 2 | wanning
# Processing record count 17 of set 2 | hobyo
# Processing record count 18 of set 2 | lumeje
# Processing record count 19 of set 2 | touros
# Processing record count 20 of set 2 | mabaruma
# Processing record count 21 of set 2 | mataura
# Processing record count 22 of set 2 | upernavik
# Processing record count 23 of set 2 | mariental
# Processing record count 24 of set 2 | norman wells
# Processing record count 25 of set 2 | bafq
# Processing record count 26 of set 2 | hilo
# Processing record count 27 of set 2 | tuktoyaktuk
# Processing record count 28 of set 2 | krasnoselkup
# Processing record count 29 of set 2 | yellowknife
# Processing record count 30 of set 2 | alice springs
# Processing record count 31 of set 2 | punta arenas
# Processing record count 32 of set 2 | sao filipe
# Processing record count 33 of set 2 | krasnyy chikoy
# Processing record count 34 of set 2 | lavrentiya
# Processing record count 35 of set 2 | alofi
# Processing record count 36 of set 2 | palmer
# Processing record count 37 of set 2 | torbay
# Processing record count 38 of set 2 | kodiak
# Processing record count 39 of set 2 | zeya
# Processing record count 40 of set 2 | isangel
# City not found. Skipping...
# Processing record count 41 of set 2 | abha
# Processing record count 42 of set 2 | port elizabeth
# Processing record count 43 of set 2 | arraial do cabo
# City not found. Skipping...
# Processing record count 44 of set 2 | mahebourg
# Processing record count 45 of set 2 | chokurdakh
# Processing record count 46 of set 2 | leninskoye
# Processing record count 1 of set 3 | cap malheureux
# Processing record count 2 of set 3 | atasu
# Processing record count 3 of set 3 | mgandu
# Processing record count 4 of set 3 | iztapa
# Processing record count 5 of set 3 | smithers
# Processing record count 6 of set 3 | luchegorsk
# Processing record count 7 of set 3 | vaini
# Processing record count 8 of set 3 | cape town
# Processing record count 9 of set 3 | severo-kurilsk
# Processing record count 10 of set 3 | velsk
# Processing record count 11 of set 3 | dobson
# Processing record count 12 of set 3 | beyneu
# Processing record count 13 of set 3 | salalah
# Processing record count 14 of set 3 | port hardy
# Processing record count 15 of set 3 | chuy
# Processing record count 16 of set 3 | rondonopolis
# Processing record count 17 of set 3 | americus
# Processing record count 18 of set 3 | dinanagar
# Processing record count 19 of set 3 | camocim
# Processing record count 20 of set 3 | mount gambier
# Processing record count 21 of set 3 | ligayan
# Processing record count 22 of set 3 | bengkulu
# Processing record count 23 of set 3 | boa vista
# Processing record count 24 of set 3 | kamaishi
# Processing record count 25 of set 3 | jackson
# Processing record count 26 of set 3 | cururupu
# Processing record count 27 of set 3 | lebu
# City not found. Skipping...
# Processing record count 28 of set 3 | faanui
# City not found. Skipping...
# Processing record count 29 of set 3 | dikson
# Processing record count 30 of set 3 | amos
# Processing record count 31 of set 3 | paveh
# Processing record count 32 of set 3 | adre
# Processing record count 33 of set 3 | roma
# Processing record count 34 of set 3 | naze
# Processing record count 35 of set 3 | challapata
# Processing record count 36 of set 3 | atambua
# Processing record count 37 of set 3 | vrangel
# Processing record count 38 of set 3 | avarua
# Processing record count 39 of set 3 | lorengau
# Processing record count 40 of set 3 | sur
# City not found. Skipping...
# City not found. Skipping...
# Processing record count 41 of set 3 | aklavik
# City not found. Skipping...
# Processing record count 42 of set 3 | guhagar
# Processing record count 43 of set 3 | alausi
# Processing record count 44 of set 3 | tessalit
# City not found. Skipping...
# Processing record count 1 of set 4 | nanortalik
# Processing record count 2 of set 4 | abu dhabi
# Processing record count 3 of set 4 | hede
# Processing record count 4 of set 4 | bradford
# City not found. Skipping...
# Processing record count 5 of set 4 | gat
# Processing record count 6 of set 4 | bayonet point
# Processing record count 7 of set 4 | pangody
# Processing record count 8 of set 4 | antalya
# City not found. Skipping...
# City not found. Skipping...
# Processing record count 9 of set 4 | airai
# Processing record count 10 of set 4 | bolitoc
# Processing record count 11 of set 4 | verkhniy uslon
# Processing record count 12 of set 4 | paducah
# Processing record count 13 of set 4 | aitape
# City not found. Skipping...
# Processing record count 14 of set 4 | east london
# Processing record count 15 of set 4 | el carrizo
# Processing record count 16 of set 4 | letnyaya stavka
# Processing record count 17 of set 4 | north platte
# Processing record count 18 of set 4 | de haan
# Processing record count 19 of set 4 | manaquiri
# Processing record count 20 of set 4 | koungou
# Processing record count 21 of set 4 | puerto ayacucho
# Processing record count 22 of set 4 | hamilton
# Processing record count 23 of set 4 | coquimbo
# Processing record count 24 of set 4 | carnarvon
# Processing record count 25 of set 4 | salta
# Processing record count 26 of set 4 | forest
# Processing record count 27 of set 4 | normandin
# Processing record count 28 of set 4 | nchelenge
# Processing record count 29 of set 4 | san cristobal
# City not found. Skipping...
# Processing record count 30 of set 4 | nuevo emperador
# Processing record count 31 of set 4 | pestretsy
# Processing record count 32 of set 4 | vetluzhskiy
# Processing record count 33 of set 4 | macas
# Processing record count 34 of set 4 | kulhudhuffushi
# Processing record count 35 of set 4 | rawson
# Processing record count 36 of set 4 | mount isa
# Processing record count 37 of set 4 | tupa
# Processing record count 38 of set 4 | namatanai
# City not found. Skipping...
# Processing record count 39 of set 4 | thinadhoo
# Processing record count 40 of set 4 | fort nelson
# Processing record count 41 of set 4 | novyy urgal
# Processing record count 42 of set 4 | susehri
# Processing record count 43 of set 4 | kruisfontein
# City not found. Skipping...
# Processing record count 1 of set 5 | zelenoborsk
# Processing record count 2 of set 5 | greymouth
# Processing record count 3 of set 5 | ixtapa
# Processing record count 4 of set 5 | chapais
# Processing record count 5 of set 5 | pevek
# Processing record count 6 of set 5 | saint anthony
# Processing record count 7 of set 5 | ostrovnoy
# Processing record count 8 of set 5 | dingle
# Processing record count 9 of set 5 | iqaluit
# Processing record count 10 of set 5 | bambous virieux
# Processing record count 11 of set 5 | kavieng
# Processing record count 12 of set 5 | nipawin
# Processing record count 13 of set 5 | hambantota
# Processing record count 14 of set 5 | kirundo
# Processing record count 15 of set 5 | souillac
# Processing record count 16 of set 5 | tasiilaq
# Processing record count 17 of set 5 | kununurra
# Processing record count 18 of set 5 | pratapgarh
# Processing record count 19 of set 5 | livingstonia
# Processing record count 20 of set 5 | ucluelet
# Processing record count 21 of set 5 | honiara
# Processing record count 22 of set 5 | khatanga
# Processing record count 23 of set 5 | ahipara
# Processing record count 24 of set 5 | saiha
# Processing record count 25 of set 5 | qaanaaq
# Processing record count 26 of set 5 | adeje
# Processing record count 27 of set 5 | mina
# Processing record count 28 of set 5 | fukue
# Processing record count 29 of set 5 | teya
# Processing record count 30 of set 5 | joshimath
# Processing record count 31 of set 5 | lompoc
# Processing record count 32 of set 5 | belmonte
# City not found. Skipping...
# Processing record count 33 of set 5 | bermejo
# Processing record count 34 of set 5 | reyes
# Processing record count 35 of set 5 | belonia
# City not found. Skipping...
# Processing record count 36 of set 5 | arlit
# City not found. Skipping...
# Processing record count 37 of set 5 | vermillion
# Processing record count 38 of set 5 | vardo
# Processing record count 39 of set 5 | kendari
# City not found. Skipping...
# Processing record count 40 of set 5 | ancud
# Processing record count 41 of set 5 | walvis bay
# Processing record count 42 of set 5 | burewala
# Processing record count 43 of set 5 | buchanan
# Processing record count 44 of set 5 | zanjan
# Processing record count 45 of set 5 | lasa
# Processing record count 46 of set 5 | darhan
# Processing record count 1 of set 6 | leshukonskoye
# Processing record count 2 of set 6 | new norfolk
# Processing record count 3 of set 6 | san patricio
# Processing record count 4 of set 6 | jalu
# Processing record count 5 of set 6 | ribeira grande
# Processing record count 6 of set 6 | aswan
# Processing record count 7 of set 6 | portland
# Processing record count 8 of set 6 | bethel
# Processing record count 9 of set 6 | macenta
# Processing record count 10 of set 6 | sharlyk
# Processing record count 11 of set 6 | boyolangu
# Processing record count 12 of set 6 | ewa beach
# Processing record count 13 of set 6 | northam
# Processing record count 14 of set 6 | brokopondo
# Processing record count 15 of set 6 | reitz
# Processing record count 16 of set 6 | moranbah
# City not found. Skipping...
# Processing record count 17 of set 6 | leningradskiy
# Processing record count 18 of set 6 | bartica
# Processing record count 19 of set 6 | puerto del rosario
# Processing record count 20 of set 6 | ibra
# Processing record count 21 of set 6 | kurumkan
# Processing record count 22 of set 6 | burbank
# City not found. Skipping...
# Processing record count 23 of set 6 | cidreira
# Processing record count 24 of set 6 | atar
# Processing record count 25 of set 6 | taltal
# Processing record count 26 of set 6 | komsomolskiy
# Processing record count 27 of set 6 | westerland
# City not found. Skipping...
# Processing record count 28 of set 6 | paamiut
# Processing record count 29 of set 6 | katangli
# Processing record count 30 of set 6 | grand-santi
# Processing record count 31 of set 6 | birao
# Processing record count 32 of set 6 | saldanha
# Processing record count 33 of set 6 | san quintin
# Processing record count 34 of set 6 | petropavlovskoye
# Processing record count 35 of set 6 | atuona
# Processing record count 36 of set 6 | umarkot
# Processing record count 37 of set 6 | korla
# Processing record count 38 of set 6 | puerto maldonado
# Processing record count 39 of set 6 | yulara
# Processing record count 40 of set 6 | yendi
# Processing record count 41 of set 6 | motihari
# Processing record count 42 of set 6 | quatre cocos
# Processing record count 43 of set 6 | san ramon de la nueva oran
# Processing record count 44 of set 6 | praya
# Processing record count 45 of set 6 | pangnirtung
# Processing record count 46 of set 6 | alyangula
# Processing record count 47 of set 6 | tricase
# Processing record count 1 of set 7 | parbhani
# Processing record count 2 of set 7 | lindas
# City not found. Skipping...
# Processing record count 3 of set 7 | necochea
# Processing record count 4 of set 7 | omsukchan
# Processing record count 5 of set 7 | lubao
# Processing record count 6 of set 7 | bandarbeyla
# Processing record count 7 of set 7 | zacatecoluca
# Processing record count 8 of set 7 | maturin
# Processing record count 9 of set 7 | geraldton
# Processing record count 10 of set 7 | brookhaven
# Processing record count 11 of set 7 | codrington
# Processing record count 12 of set 7 | longyearbyen
# Processing record count 13 of set 7 | okha
# Processing record count 14 of set 7 | bairiki
# City not found. Skipping...
# Processing record count 15 of set 7 | ahuimanu
# Processing record count 16 of set 7 | sumbawanga
# Processing record count 17 of set 7 | cockburn town
# Processing record count 18 of set 7 | baglan
# Processing record count 19 of set 7 | caravelas
# Processing record count 20 of set 7 | eureka
# Processing record count 21 of set 7 | nizhnyaya poyma
# Processing record count 22 of set 7 | porlamar
# Processing record count 23 of set 7 | balikpapan
# Processing record count 24 of set 7 | richards bay
# Processing record count 25 of set 7 | bluefield
# Processing record count 26 of set 7 | custoias
# Processing record count 27 of set 7 | klaksvik
# Processing record count 28 of set 7 | tuatapere
# Processing record count 29 of set 7 | kemijarvi
# Processing record count 30 of set 7 | goya
# Processing record count 31 of set 7 | igarka
# Processing record count 32 of set 7 | mao
# Processing record count 33 of set 7 | yar-sale
# Processing record count 34 of set 7 | la reforma
# Processing record count 35 of set 7 | aquin
# Processing record count 36 of set 7 | broome
# Processing record count 37 of set 7 | san borja
# Processing record count 38 of set 7 | shitanjing
# Processing record count 39 of set 7 | sitka
# City not found. Skipping...
# Processing record count 40 of set 7 | chicama
# City not found. Skipping...
# Processing record count 41 of set 7 | havelock
# Processing record count 42 of set 7 | vostok
# Processing record count 43 of set 7 | sola
# Processing record count 44 of set 7 | changchun
# Processing record count 45 of set 7 | varhaug
# Processing record count 46 of set 7 | guaratinga
# Processing record count 1 of set 8 | tiksi
# Processing record count 2 of set 8 | kaa-khem
# Processing record count 3 of set 8 | moose factory
# Processing record count 4 of set 8 | pouebo
# City not found. Skipping...
# Processing record count 5 of set 8 | constitucion
# Processing record count 6 of set 8 | sibolga
# Processing record count 7 of set 8 | lake cowichan
# Processing record count 8 of set 8 | zhigansk
# Processing record count 9 of set 8 | namibe
# Processing record count 10 of set 8 | sechura
# Processing record count 11 of set 8 | havre
# Processing record count 12 of set 8 | adrar
# Processing record count 13 of set 8 | gushikawa
# Processing record count 14 of set 8 | anloga
# Processing record count 15 of set 8 | palembang
# Processing record count 16 of set 8 | yulin
# Processing record count 17 of set 8 | banjarmasin
# Processing record count 18 of set 8 | koumac
# Processing record count 19 of set 8 | camana
# Processing record count 20 of set 8 | strezhevoy
# Processing record count 21 of set 8 | mangrol
# Processing record count 22 of set 8 | trairi
# Processing record count 23 of set 8 | kijang
# Processing record count 24 of set 8 | astoria
# Processing record count 25 of set 8 | itaituba
# Processing record count 26 of set 8 | grindavik
# Processing record count 27 of set 8 | kindu
# Processing record count 28 of set 8 | benguela
# Processing record count 29 of set 8 | inta
# Processing record count 30 of set 8 | katsuura
# Processing record count 31 of set 8 | sao jose da coroa grande
# Processing record count 32 of set 8 | kavaratti
# Processing record count 33 of set 8 | pakala
# Processing record count 34 of set 8 | havoysund
# Processing record count 35 of set 8 | luwuk
# Processing record count 36 of set 8 | kismayo
# Processing record count 37 of set 8 | lakatoro
# Processing record count 38 of set 8 | mata
# Processing record count 39 of set 8 | darab
# Processing record count 40 of set 8 | puerto colombia
# Processing record count 41 of set 8 | laureles
# Processing record count 42 of set 8 | kirkuk
# Processing record count 43 of set 8 | sobolevo
# Processing record count 44 of set 8 | inuvik
# Processing record count 45 of set 8 | batagay-alyta
# Processing record count 46 of set 8 | san francisco
# City not found. Skipping...
# Processing record count 47 of set 8 | yamada
# Processing record count 48 of set 8 | yauya
# Processing record count 1 of set 9 | taunsa
# Processing record count 2 of set 9 | vao
# Processing record count 3 of set 9 | hwange
# City not found. Skipping...
# Processing record count 4 of set 9 | farafenni
# Processing record count 5 of set 9 | tomatlan
# Processing record count 6 of set 9 | amahai
# Processing record count 7 of set 9 | skjervoy
# Processing record count 8 of set 9 | san juan
# Processing record count 9 of set 9 | seydi
# City not found. Skipping...
# Processing record count 10 of set 9 | margate
# Processing record count 11 of set 9 | jutai
# City not found. Skipping...
# Processing record count 12 of set 9 | ilulissat
# Processing record count 13 of set 9 | port moresby
# Processing record count 14 of set 9 | sibu
# Processing record count 15 of set 9 | marzuq
# Processing record count 16 of set 9 | merauke
# Processing record count 17 of set 9 | sirsa
# Processing record count 18 of set 9 | kalmunai
# Processing record count 19 of set 9 | shache
# Processing record count 20 of set 9 | mehamn
# Processing record count 21 of set 9 | general roca
# Processing record count 22 of set 9 | jizan
# Processing record count 23 of set 9 | old town
# Processing record count 24 of set 9 | soyo
# Processing record count 25 of set 9 | caluquembe
# Processing record count 26 of set 9 | sakakah
# Processing record count 27 of set 9 | aykhal
# Processing record count 28 of set 9 | liverpool
# Processing record count 29 of set 9 | labuan
# Processing record count 30 of set 9 | tahoua
# City not found. Skipping...
# Processing record count 31 of set 9 | bolshoye selo
# Processing record count 32 of set 9 | ozernovskiy
# Processing record count 33 of set 9 | lhokseumawe
# Processing record count 34 of set 9 | ca mau
# City not found. Skipping...
# Processing record count 35 of set 9 | vila do maio
# Processing record count 36 of set 9 | kahului
# Processing record count 37 of set 9 | vila velha
# City not found. Skipping...
# Processing record count 38 of set 9 | port lincoln
# Processing record count 39 of set 9 | camacha
# Processing record count 40 of set 9 | berdigestyakh
# Processing record count 41 of set 9 | bulungu
# Processing record count 42 of set 9 | hofn
# Processing record count 43 of set 9 | sorland
# Processing record count 44 of set 9 | severnyy
# Processing record count 1 of set 10 | los naranjos
# Processing record count 2 of set 10 | rocha
# Processing record count 3 of set 10 | georgetown
# Processing record count 4 of set 10 | pimentel
# Processing record count 5 of set 10 | sosva
# Processing record count 6 of set 10 | victoria
# Processing record count 7 of set 10 | sorso
# Processing record count 8 of set 10 | ures
# Processing record count 9 of set 10 | pitimbu
# Processing record count 10 of set 10 | antofagasta
# Processing record count 11 of set 10 | narsaq
# Processing record count 12 of set 10 | atherton
# Processing record count 13 of set 10 | aanekoski
# Processing record count 14 of set 10 | bafra
# Processing record count 15 of set 10 | torres
# Processing record count 16 of set 10 | kirakira
# Processing record count 17 of set 10 | manakara
# Processing record count 18 of set 10 | trelew
# Processing record count 19 of set 10 | karpogory
# Processing record count 20 of set 10 | road town
# Processing record count 21 of set 10 | youghal
# Processing record count 22 of set 10 | kimbe
# Processing record count 23 of set 10 | san antonio
# City not found. Skipping...
# Processing record count 24 of set 10 | westport
# Processing record count 25 of set 10 | shimoda
# Processing record count 26 of set 10 | north bend
# Processing record count 27 of set 10 | husavik
# Processing record count 28 of set 10 | catuday
# Processing record count 29 of set 10 | valdivia
# Processing record count 30 of set 10 | phalodi
# City not found. Skipping...
# Processing record count 31 of set 10 | te anau
# Processing record count 32 of set 10 | okhotsk
# Processing record count 33 of set 10 | flin flon
# Processing record count 34 of set 10 | valdemoro
# Processing record count 35 of set 10 | jhudo
# Processing record count 36 of set 10 | waingapu
# Processing record count 37 of set 10 | provideniya
# Processing record count 38 of set 10 | celestun
# Processing record count 39 of set 10 | aquiles serdan
# Processing record count 40 of set 10 | zimmi
# City not found. Skipping...
# Processing record count 41 of set 10 | aracati
# Processing record count 42 of set 10 | kalemie
# Processing record count 43 of set 10 | gravdal
# Processing record count 44 of set 10 | grand gaube
# Processing record count 45 of set 10 | campoverde
# Processing record count 46 of set 10 | jhol
# Processing record count 47 of set 10 | ayr
# Processing record count 1 of set 11 | nabire
# Processing record count 2 of set 11 | manono
# Processing record count 3 of set 11 | belaya gora
# Processing record count 4 of set 11 | leh
# Processing record count 5 of set 11 | stykkisholmur
# Processing record count 6 of set 11 | halifax
# Processing record count 7 of set 11 | khanpur
# Processing record count 8 of set 11 | manoharpur
# Processing record count 9 of set 11 | isla vista
# Processing record count 10 of set 11 | beringovskiy
# Processing record count 11 of set 11 | yerofey pavlovich
# Processing record count 12 of set 11 | lattes
# Processing record count 13 of set 11 | praia da vitoria
# Processing record count 14 of set 11 | saint-augustin
# City not found. Skipping...
# Processing record count 15 of set 11 | cukai
# Processing record count 16 of set 11 | mahon
# Processing record count 17 of set 11 | trojes
# Processing record count 18 of set 11 | demyansk
# Processing record count 19 of set 11 | xinqing
# Processing record count 20 of set 11 | podyuga
# Processing record count 21 of set 11 | bangassou
# Processing record count 22 of set 11 | ukholovo
# Processing record count 23 of set 11 | shintomi
# City not found. Skipping...
# Processing record count 24 of set 11 | tondano
# Processing record count 25 of set 11 | finote selam
# Processing record count 26 of set 11 | port hedland
# Processing record count 27 of set 11 | port blair
# Processing record count 28 of set 11 | asau
# Processing record count 29 of set 11 | puerto escondido
# Processing record count 30 of set 11 | axim
# Processing record count 31 of set 11 | kongwa
# Processing record count 32 of set 11 | cascais
# Processing record count 33 of set 11 | panguipulli
# Processing record count 34 of set 11 | iwanai
# City not found. Skipping...
# Processing record count 35 of set 11 | russell
# Processing record count 36 of set 11 | oranjestad
# Processing record count 37 of set 11 | buraydah
# Processing record count 38 of set 11 | webuye
# Processing record count 39 of set 11 | punta gorda
# Processing record count 40 of set 11 | nome
# Processing record count 41 of set 11 | inhambane
# Processing record count 42 of set 11 | semporna
# Processing record count 43 of set 11 | pinsk
# Processing record count 44 of set 11 | nelson bay
# Processing record count 45 of set 11 | andenes
# Processing record count 46 of set 11 | hami
# Processing record count 47 of set 11 | zhezkazgan
# City not found. Skipping...
# Processing record count 1 of set 12 | claremore
# Processing record count 2 of set 12 | santo antonio do taua
# Processing record count 3 of set 12 | vila
# Processing record count 4 of set 12 | bonthe
# Processing record count 5 of set 12 | macapa
# Processing record count 6 of set 12 | shirokiy
# Processing record count 7 of set 12 | sayyan
# Processing record count 8 of set 12 | thabazimbi
# Processing record count 9 of set 12 | bosaso
# Processing record count 10 of set 12 | savonlinna
# Processing record count 11 of set 12 | sapa
# City not found. Skipping...
# Processing record count 12 of set 12 | riohacha
# Processing record count 13 of set 12 | morondava
# Processing record count 14 of set 12 | amga
# Processing record count 15 of set 12 | lydenburg
# Processing record count 16 of set 12 | rio de janeiro
# Processing record count 17 of set 12 | teguise
# Processing record count 18 of set 12 | araouane
# Processing record count 19 of set 12 | vaitape
# Processing record count 20 of set 12 | zhangye
# Processing record count 21 of set 12 | chuari khas
# City not found. Skipping...
# Processing record count 22 of set 12 | pangkalanbuun
# Processing record count 23 of set 12 | yerbogachen
# Processing record count 24 of set 12 | maan
# Processing record count 25 of set 12 | saint-raymond
# Processing record count 26 of set 12 | zwettl
# Processing record count 27 of set 12 | jertih
# Processing record count 28 of set 12 | porto novo
# Processing record count 29 of set 12 | beloha
# Processing record count 30 of set 12 | marsabit
# Processing record count 31 of set 12 | sitio novo do tocantins
# Processing record count 32 of set 12 | isoka
# Processing record count 33 of set 12 | vestmannaeyjar
# Processing record count 34 of set 12 | muros
# Processing record count 35 of set 12 | la canada
# Processing record count 36 of set 12 | nouadhibou
# Processing record count 37 of set 12 | jinka
# Processing record count 38 of set 12 | tarko-sale
# Processing record count 39 of set 12 | tabou
# Processing record count 40 of set 12 | quepos
# Processing record count 41 of set 12 | bella vista
# Processing record count 42 of set 12 | clemencia
# Processing record count 43 of set 12 | gamba
# City not found. Skipping...
# Processing record count 44 of set 12 | uray
# Processing record count 45 of set 12 | timmins
# Processing record count 46 of set 12 | kathu
# Processing record count 1 of set 13 | soavinandriana
# Processing record count 2 of set 13 | longfeng
# Processing record count 3 of set 13 | rio grande
# Processing record count 4 of set 13 | jahanabad
# Processing record count 5 of set 13 | andilamena
# Processing record count 6 of set 13 | verkhniye tatyshly
# Processing record count 7 of set 13 | sarahan
# Processing record count 8 of set 13 | mackenzie
# Processing record count 9 of set 13 | kiama
# Processing record count 10 of set 13 | pinega
# Processing record count 11 of set 13 | cartagena del chaira
# City not found. Skipping...
# Processing record count 12 of set 13 | giyani
# Processing record count 13 of set 13 | valer
# Processing record count 14 of set 13 | svetlogorsk
# Processing record count 15 of set 13 | pacific grove
# Processing record count 16 of set 13 | bilibino
# Processing record count 17 of set 13 | ilheus
# Processing record count 18 of set 13 | comodoro rivadavia
# Processing record count 19 of set 13 | nador
# Processing record count 20 of set 13 | manta
# Processing record count 21 of set 13 | saquena
# Processing record count 22 of set 13 | vuktyl
# Processing record count 23 of set 13 | lata
# Processing record count 24 of set 13 | novopokrovka
# Processing record count 25 of set 13 | olafsvik
# Processing record count 26 of set 13 | kralendijk
# Processing record count 27 of set 13 | kokkola
# Processing record count 28 of set 13 | simao
# Processing record count 29 of set 13 | bubaque
# City not found. Skipping...
# Processing record count 30 of set 13 | garden city
# Processing record count 31 of set 13 | changli
# Processing record count 32 of set 13 | petropavlovsk-kamchatskiy
# Processing record count 33 of set 13 | anchorage
# Processing record count 34 of set 13 | kargil
# Processing record count 35 of set 13 | barcelos
# Processing record count 36 of set 13 | mananara
# Processing record count 37 of set 13 | sawakin
# Processing record count 38 of set 13 | tiznit
# Processing record count 39 of set 13 | muroto
# Processing record count 40 of set 13 | bitung
# City not found. Skipping...
# Processing record count 41 of set 13 | hervey bay
# Processing record count 42 of set 13 | kaseda
# City not found. Skipping...
# City not found. Skipping...
# Processing record count 43 of set 13 | mazamari
# City not found. Skipping...
# Processing record count 44 of set 13 | curaca
# Processing record count 1 of set 14 | dhidhdhoo
# Processing record count 2 of set 14 | da nang
# Processing record count 3 of set 14 | lannion
# Processing record count 4 of set 14 | oranjemund
# Processing record count 5 of set 14 | gurgentepe
# Processing record count 6 of set 14 | brae
# Processing record count 7 of set 14 | dunedin
# Processing record count 8 of set 14 | tromso
# Processing record count 9 of set 14 | skoghall
# Processing record count 10 of set 14 | kyren
# City not found. Skipping...
# Processing record count 11 of set 14 | saint george
# Processing record count 12 of set 14 | poum
# Processing record count 13 of set 14 | canutama
# Processing record count 14 of set 14 | voyinka
# Processing record count 15 of set 14 | barao de melgaco
# Processing record count 16 of set 14 | saint-francois
# Processing record count 17 of set 14 | marsh harbour
# Processing record count 18 of set 14 | abu samrah
# Processing record count 19 of set 14 | ketchikan
# Processing record count 20 of set 14 | ust-nera
# Processing record count 21 of set 14 | kaeo
# Processing record count 22 of set 14 | virginia beach
# Processing record count 23 of set 14 | cairns
# Processing record count 24 of set 14 | bahia honda
# Processing record count 25 of set 14 | kupang
# City not found. Skipping...
# Processing record count 26 of set 14 | palanga
# City not found. Skipping...
# Processing record count 27 of set 14 | akdepe
# City not found. Skipping...
# Processing record count 28 of set 14 | nouakchott
# Processing record count 29 of set 14 | saint-louis
# Processing record count 30 of set 14 | arman
# Processing record count 31 of set 14 | sisimiut
# Processing record count 32 of set 14 | talavera de la reina
# Processing record count 33 of set 14 | brunico
# City not found. Skipping...
# Processing record count 34 of set 14 | landau
# Processing record count 35 of set 14 | agde
# Processing record count 36 of set 14 | thanh hoa
# Processing record count 37 of set 14 | vagur
# Processing record count 38 of set 14 | high rock
# City not found. Skipping...
# Processing record count 39 of set 14 | middelburg
# Processing record count 40 of set 14 | haines junction
# Processing record count 41 of set 14 | erenhot
# Processing record count 42 of set 14 | kade
# Processing record count 43 of set 14 | changji
# Processing record count 44 of set 14 | batagay
# Processing record count 1 of set 15 | klyuchi
# Processing record count 2 of set 15 | south sioux city
# Processing record count 3 of set 15 | shangrao
# Processing record count 4 of set 15 | marsa matruh
# Processing record count 5 of set 15 | lakselv
# Processing record count 6 of set 15 | papara
# Processing record count 7 of set 15 | ambilobe
# Processing record count 8 of set 15 | waitara
# Processing record count 9 of set 15 | umm lajj
# Processing record count 10 of set 15 | corowa
# Processing record count 11 of set 15 | ouegoa
# Processing record count 12 of set 15 | dwarka
# Processing record count 13 of set 15 | verkhnechusovskiye gorodki
# City not found. Skipping...
# Processing record count 14 of set 15 | razole
# Processing record count 15 of set 15 | leua
# Processing record count 16 of set 15 | meulaboh
# Processing record count 17 of set 15 | luderitz
# Processing record count 18 of set 15 | campechuela
# City not found. Skipping...
# Processing record count 19 of set 15 | ulladulla
# Processing record count 20 of set 15 | hojai
# Processing record count 21 of set 15 | moroni
# Processing record count 22 of set 15 | kipini
# Processing record count 23 of set 15 | marienburg
# Processing record count 24 of set 15 | seoul
# Processing record count 25 of set 15 | nyurba
# Processing record count 26 of set 15 | martapura
# Processing record count 27 of set 15 | constantine
# Processing record count 28 of set 15 | taitung
# Processing record count 29 of set 15 | green river
# Processing record count 30 of set 15 | laguna
# Processing record count 31 of set 15 | ndele
# Processing record count 32 of set 15 | soignies
# Processing record count 33 of set 15 | tacuarembo
# Processing record count 34 of set 15 | kanker
# Processing record count 35 of set 15 | tazovskiy
# Processing record count 36 of set 15 | yarmouth
# Processing record count 37 of set 15 | hoquiam
# Processing record count 38 of set 15 | raichur
# Processing record count 39 of set 15 | launceston
# Processing record count 40 of set 15 | aden
# Processing record count 41 of set 15 | diu
# Processing record count 42 of set 15 | luwero
# Processing record count 43 of set 15 | ha tinh
# Processing record count 44 of set 15 | zorritos
# Processing record count 45 of set 15 | manaure
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
city_data_df = pd.DataFrame(city_data)
new_column_order = ["City", "Country", "Date", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]
city_data_df = city_data_df[new_column_order]

output_data_file = "WeatherPy_Database.csv"
city_data_df.to_csv(output_data_file, index_label="City_ID")
